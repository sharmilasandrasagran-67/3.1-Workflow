# %% [markdown]
# <a href="https://colab.research.google.com/github/sharmilasandrasagran-67/3.1-Workflow/blob/main/ci_cd_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
repo_url = "https://github.com/sharmilasandrasagran-67/File-ci-cd.git"

# %%
import pandas as pd
import matplotlib.pyplot as plt
# upload sample dataset from github
df = pd.read_csv('https://raw.githubusercontent.com/sharmilasandrasagran-67/File-ci-cd/refs/heads/main/data/dataset1.csv')
df.head()
# Out:
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
# 3   48    0                4           138          214                    0
# 4   54    1                3           150          195                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0
# 3            0             108                1      1.5         2       1
# 4            0             122                0      0.0         1       0

# %%
# Display first 5 rows
print(df.head())

# Check duplicate rows
print("Duplicate Rows:", df.duplicated().sum())

# Remove duplicates
df_cleaned = df.drop_duplicates()

# Save cleaned dataset
df_cleaned.to_csv("processed_dataset.csv", index=False)

print("Duplicates removed successfully.")
# Out:
#    age  sex  chest pain type  resting bp s  cholesterol  fasting blood sugar  \
# 0   40    1                2           140          289                    0
# 1   49    0                3           160          180                    0
# 2   37    1                2           130          283                    0
# 3   48    0                4           138          214                    0
# 4   54    1                3           150          195                    0
#
#    resting ecg  max heart rate  exercise angina  oldpeak  ST slope  target
# 0            0             172                0      0.0         1       0
# 1            0             156                0      1.0         2       1
# 2            1              98                0      0.0         1       0
# 3            0             108                1      1.5         2       1
# 4            0             122                0      0.0         1       0
# Duplicate Rows: 272
# Duplicates removed successfully.
